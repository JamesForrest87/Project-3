# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %%
# Study data files
planet_path = "planets.csv"
planet_data = pd.read_csv(planet_path )

# %%
# Display the data table for preview
planet_data
# Out:
#       p_name  rotation_period  orbital_period  diameter  \
# 0   Alderaan             24.0           364.0   12500.0
# 1   Yavin IV             24.0          4818.0   10200.0
# 2       Hoth             23.0           549.0    7200.0
# 3    Dagobah             23.0           341.0    8900.0
# 4     Bespin             12.0          5110.0  118000.0
# ..       ...              ...             ...       ...
# 56     Shili              NaN             NaN       NaN
# 57     Kalee             23.0           378.0   13850.0
# 58    Umbara              NaN             NaN       NaN
# 59  Tatooine             23.0           304.0   10465.0
# 60     Jakku              NaN             NaN       NaN
#
#                       climate                                 gravity  \
# 0                   temperate                              1 standard
# 1         temperate, tropical                              1 standard
# 2                      frozen                            1.1 standard
# ...

# %%
planet_data_rotation = planet_data[["rotation_period"]]
planet_data_rotation.plot(kind="line")
# Out:
# <Axes: >

# %%
planet_data_orbital_period = planet_data[["orbital_period"]]
planet_data_orbital_period.plot(kind="line")
# Out:
# <Axes: >

# %%
planet_data_diameter = planet_data[["diameter"]]
planet_data_diameter.plot(kind="line")
# Out:
# <Axes: >

# %%
planet_data_surface_water = planet_data[["surface_water"]]
planet_data_surface_water.plot(kind="line")
# Out:
# <Axes: >

# %%
planet_data_population = planet_data[["population"]]
planet_data_population.plot(kind="line")
# Out:
# <Axes: >

# %%
planet_data.columns
# Out:
# Index(['p_name', 'rotation_period', 'orbital_period', 'diameter', 'climate',
#        'gravity', 'terrain', 'surface_water', 'population'],
#       dtype='object')

# %%
planet_data.dtypes
# Out:
# p_name              object
# rotation_period    float64
# orbital_period     float64
# diameter           float64
# climate             object
# gravity             object
# terrain             object
# surface_water      float64
# population         float64
# dtype: object
